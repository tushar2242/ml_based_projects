# %%
import spacy
from string import punctuation
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
text = ["""Node.js is a cross-platform, open-source server environment that can run on Windows, Linux, Unix, macOS, and more. Node.js is a back-end JavaScript runtime environment, runs on the V8 JavaScript engine, and executes JavaScript code outside a web browser.

Node.js lets developers use JavaScript to write command line tools and for server-side scripting. The ability to run JavaScript code on the server is often used to generate dynamic web page content before the page is sent to the user's web browser. Consequently, Node.js represents a "JavaScript everywhere" paradigm,[5] unifying web-application development around a single programming language, as opposed to using different languages for the server- versus client-side programming.

Node.js has an event-driven architecture capable of asynchronous I/O. These design choices aim to optimize throughput and scalability in web applications with many input/output operations, as well as for real-time Web applications (e.g., real-time communication programs and browser games).[6]

The Node.js distributed development project was previously governed by the Node.js Foundation,[7] and has now merged with the JS Foundation to form the OpenJS Foundation. OpenJS Foundation is facilitated by the Linux Foundation's Collaborative Projects program.[8]

History

Ryan Dahl, creator of Node.js, in 2010
Node.js was written initially by Ryan Dahl in 2009,[9] about thirteen years after the introduction of the first server-side JavaScript environment, Netscape's LiveWire Pro Web.[10] The initial release supported only Linux and Mac OS X. Its development and maintenance was led by Dahl and later sponsored by Joyent.[11]

Dahl criticized the limited possibilities of the most popular web server in 2009, Apache HTTP Server, to handle a lot of concurrent connections (up to 10,000 and more) and the most common way of creating code (sequential programming), when code either blocked the entire process or implied multiple execution stacks in the case of simultaneous connections.[12]

Dahl demonstrated the project at the inaugural European JSConf on November 8, 2009.[13][14][15] Node.js combined Google's V8 JavaScript engine, an event loop, and a low-level I/O API.[16]

In January 2010, a package manager was introduced for the Node.js environment called npm.[17] The package manager makes it easier for programmers to publish and share source code of Node.js packages and is designed to simplify installation, updating, and uninstallation of packages.[16]

In June 2011, Microsoft and Joyent implemented a native Windows version of Node.js.[18] The first Node.js build supporting Windows was released in July 2011.

In January 2012, Dahl stepped aside, promoting coworker and npm creator Isaac Schlueter to manage the project.[19] In January 2014, Schlueter announced that Timothy J. Fontaine would lead the project.[20]

In December 2014, Fedor Indutny started io.js, a fork of Node.js. Due to the internal conflict over Joyent's governance, io.js was created as an open governance alternative with a separate technical committee.[21][22] Unlike Node.js,[23] the authors planned to keep io.js up-to-date with the latest releases of the Google V8 JavaScript engine.[24]

In February 2015, the intent to form a neutral Node.js Foundation was announced. By June 2015, the Node.js and io.js communities voted to work together under the Node.js Foundation.[25]

In September 2015, Node.js v0.12 and io.js v3.3 were merged back together into Node v4.0.[26] This merge brought V8 ES6 features into Node.js and a long-term support release cycle.[27] As of 2016, the io.js website recommends that developers switch back to Node.js and that no further releases of io.js are planned due to the merge.[28]

In 2019, the JS Foundation and Node.js Foundation merged to form the OpenJS Foundation.

On March 15 2023, Node.js 19.8.1 was released.[29]

Overview
Node.js allows the creation of Web servers and networking tools using JavaScript and a collection of "modules" that handle various core functionalities.[13][16][30][31][32] Modules are provided for file system I/O, networking (DNS, HTTP, TCP, TLS/SSL, or UDP), binary data (buffers), cryptography functions, data streams, and other core functions.[16][31][33] Node.js's modules use an API designed to reduce the complexity of writing server applications.[16][31]

JavaScript is the only language that Node.js supports natively, but many compile-to-JS languages are available.[34] As a result, Node.js applications can be written in CoffeeScript,[35] Dart, TypeScript, ClojureScript and others.

Node.js is primarily used to build network programs such as Web servers.[30] The most significant difference between Node.js and PHP is that most functions in PHP block until completion (commands execute only after previous commands finish), while Node.js functions are non-blocking (commands execute concurrently or even in parallel,[36][37] and use callbacks to signal completion or failure).[30]

Node.js is officially supported on Linux, macOS and Microsoft Windows 8.1 and Server 2012 (and later),[2] with tier 2 support for SmartOS and IBM AIX and experimental support for FreeBSD. OpenBSD also works, and LTS versions available for IBM i (AS/400).[38] The provided source code may also be built on similar operating systems to those officially supported or be modified by third parties to support others such as NonStop OS[39] and Unix servers."""]

# %%
# cleaned_text = text.replace('\n\n','')
# cleaned_text = cleaned_text.replace('\ ','')
# cleaned_text = cleaned_text.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 cleaned_text = text.replace('\n\n','')
#       2 cleaned_text = cleaned_text.replace('\ ','')
#       3 cleaned_text = cleaned_text.lower()
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
stop_words = list(STOP_WORDS)

# %%
nlp =spacy.load("en_core_web_sm")

# %%
doc = nlp(cleaned_text)

# %%
token = [token.text for token in doc]

# %%
# token

# %%
# Define and configure the TF-IDF vectorizer
vectorizer = TfidfVectorizer(
    max_df=0.85,  # Exclude terms appearing in more than 85% of documents
    min_df=2,     # Exclude terms appearing in fewer than 2 documents
    stop_words=None,  # Do not remove stop words
    lowercase=True,   # Convert text to lowercase
)

# vectorizer.fit(token)

# %%
# Fit and transform your text data to obtain TF-IDF vectors
tfidf_vectors = vectorizer.fit_transform(text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 2
#       1 # Fit and transform your text data to obtain TF-IDF vectors
# ----> 2 tfidf_vectors = vectorizer.fit_transform(text)
#
# File D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py:2131, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2124 self._check_params()
#    2125 self._tfidf = TfidfTransformer(
#    2126     norm=self.norm,
#    2127     use_idf=self.use_idf,
#    2128     smooth_idf=self.smooth_idf,
#    2129     sublinear_tf=self.sublinear_tf,
#    2130 )
# -> 2131 X = super().fit_transform(raw_documents)
#    2132 self._tfidf.fit(X)
#    2133 # X is already a transformed view of raw_documents so
#    2134 # we set copy to False
#
# File D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py:1397, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1395 min_doc_count = min_df if isinstance(min_df, Integral) else min_df * n_doc
#    1396 if max_doc_count < min_doc_count:
# -> 1397     raise ValueError("max_df corresponds to < documents than min_df")
#    1398 if max_features is not None:
#    1399     X = self._sort_features(X, vocabulary)
#
# ValueError: max_df corresponds to < documents than min_df

# %%
# tfidf_vectors = vectorizer.transform(token)

# %%
# vectorizer.vocabulary_
# Out:
# {'node': 245,
#  'js': 199,
#  'is': 192,
#  'cross': 115,
#  'platform': 279,
#  'open': 256,
#  'source': 326,
#  'server': 315,
#  'environment': 140,
#  'that': 344,
#  'can': 82,
#  'run': 304,
#  'on': 254,
#  'windows': 390,
#  'linux': 214,
#  'unix': 364,
#  'macos': 222,
#  'and': 50,
#  'more': 235,
#  'back': 65,
#  'end': 137,
#  'javascript': 197,
#  'runtime': 306,
#  'runs': 305,
#  'the': 345,
#  'v8': 376,
#  'engine': 138,
#  'executes': 147,
#  'code': 88,
#  'outside': 268,
#  'web': 384,
#  'browser': 74,
#  'lets': 210,
#  'developers': 126,
#  'use': 369,
#  'to': 356,
#  'write': 395,
#  'command': 93,
#  'line': 213,
#  'tools': 358,
#  'for': 159,
#  'side': 318,
#  'scripting': 310,
#  'ability': 41,
#  'often': 253,
#  'used': 370,
#  'generate': 168,
#  'dynamic': 134,
#  'page': 273,
#  'content': 107,
#  'before': 67,
#  'sent': 311,
#  'user': 371,
#  'consequently': 106,
#  'represents': 302,
#  'everywhere': 145,
#  'paradigm': 274,
#  'unifying': 362,
#  'application': 54,
#  'development': 127,
#  'around': 58,
#  'single': 324,
#  'programming': 289,
#  'language': 204,
#  'as': 59,
#  'opposed': 261,
#  'using': 372,
#  'different': 129,
#  'languages': 205,
#  'versus': 380,
#  'client': 86,
#  'has': 173,
#  'an': 49,
#  'event': 144,
#  'driven': 132,
#  'architecture': 56,
#  'capable': 83,
#  'of': 251,
#  'asynchronous': 61,
#  'these': 346,
#  'design': 124,
#  'choices': 85,
#  'aim': 44,
#  'optimize': 262,
#  'throughput': 351,
#  'scalability': 308,
#  'in': 179,
#  'applications': 55,
#  'with': 391,
#  'many': 227,
#  'input': 184,
#  'output': 267,
#  'operations': 260,
#  'well': 386,
#  'real': 296,
#  'time': 353,
#  'communication': 97,
#  'programs': 290,
#  'games': 167,
#  'distributed': 130,
#  'project': 291,
#  'was': 382,
#  'previously': 283,
#  'governed': 171,
#  'by': 79,
#  'foundation': 162,
#  'now': 249,
#  'merged': 231,
#  'form': 161,
#  'openjs': 258,
#  'facilitated': 150,
#  'collaborative': 90,
#  'projects': 292,
#  'program': 287,
#  'historyryan': 174,
#  'dahl': 118,
#  'creator': 113,
#  '2010': 13,
#  'written': 397,
#  'initially': 183,
#  'ryan': 307,
#  '2009': 12,
#  'about': 42,
#  'thirteen': 348,
#  'years': 398,
#  'after': 43,
#  'introduction': 190,
#  'first': 157,
#  'netscape': 240,
#  'livewire': 215,
#  'pro': 285,
#  '10': 1,
#  'initial': 182,
#  'release': 299,
#  'supported': 335,
#  'only': 255,
#  'mac': 221,
#  'os': 264,
#  'its': 195,
#  'maintenance': 223,
#  'led': 209,
#  'later': 206,
#  'sponsored': 327,
#  'joyent': 198,
#  '11': 2,
#  'criticized': 114,
#  'limited': 212,
#  'possibilities': 281,
#  'most': 236,
#  'popular': 280,
#  'apache': 52,
#  'http': 175,
#  'handle': 172,
#  'lot': 218,
#  'concurrent': 102,
#  'connections': 105,
#  'up': 367,
#  '000': 0,
#  'common': 96,
#  'way': 383,
#  'creating': 111,
#  'sequential': 314,
#  'when': 388,
#  'either': 136,
#  'blocked': 71,
#  'entire': 139,
#  'process': 286,
#  'or': 263,
#  'implied': 178,
#  'multiple': 237,
#  'execution': 148,
#  'stacks': 329,
#  'case': 84,
#  'simultaneous': 323,
#  '12': 3,
#  'demonstrated': 123,
#  'at': 62,
#  'inaugural': 180,
#  'european': 142,
#  'jsconf': 200,
#  'november': 248,
#  '13': 4,
#  '14': 5,
#  '15': 6,
#  'combined': 92,
#  'google': 169,
#  'loop': 217,
#  'low': 219,
#  'level': 211,
#  'api': 53,
#  '16': 7,
#  'january': 196,
#  'package': 271,
#  'manager': 226,
#  'introduced': 189,
#  'called': 81,
#  'npm': 250,
#  '17': 8,
#  'makes': 224,
#  'it': 194,
#  'easier': 135,
#  'programmers': 288,
#  'publish': 295,
#  'share': 317,
#  'packages': 272,
#  'designed': 125,
#  'simplify': 322,
#  'installation': 185,
#  'updating': 368,
#  'uninstallation': 363,
#  'june': 202,
#  '2011': 14,
#  'microsoft': 232,
#  'implemented': 177,
#  'native': 238,
#  'version': 378,
#  '18': 9,
#  'build': 76,
#  'supporting': 336,
#  'released': 300,
#  'july': 201,
#  '2012': 15,
#  'stepped': 331,
#  'aside': 60,
#  'promoting': 293,
#  'coworker': 109,
#  'isaac': 193,
#  'schlueter': 309,
#  'manage': 225,
#  '19': 10,
#  '2014': 16,
#  'announced': 51,
#  'timothy': 354,
#  'fontaine': 158,
#  'would': 394,
#  'lead': 208,
#  '20': 11,
#  'december': 122,
#  'fedor': 154,
#  'indutny': 181,
#  'started': 330,
#  'io': 191,
#  'fork': 160,
#  'due': 133,
#  'internal': 187,
#  'conflict': 104,
#  'over': 269,
#  'governance': 170,
#  'created': 110,
#  'alternative': 48,
#  'separate': 312,
#  'technical': 342,
#  'committee': 95,
#  '21': 21,
#  '22': 22,
#  'unlike': 365,
#  '23': 23,
#  'authors': 63,
#  'planned': 278,
#  'keep': 203,
#  'date': 121,
#  'latest': 207,
#  'releases': 301,
#  '24': 24,
#  'february': 153,
#  '2015': 17,
#  'intent': 186,
#  'neutral': 243,
#  'communities': 98,
#  'voted': 381,
#  'work': 392,
#  'together': 357,
#  'under': 361,
#  '25': 25,
#  'september': 313,
#  'v0': 373,
#  'v3': 374,
#  'were': 387,
#  'into': 188,
#  'v4': 375,
#  '26': 26,
#  'this': 349,
#  'merge': 230,
#  'brought': 73,
#  'es6': 141,
#  'features': 152,
#  'long': 216,
#  'term': 343,
#  'support': 334,
#  'cycle': 117,
#  '27': 27,
#  '2016': 18,
#  'website': 385,
#  'recommends': 297,
#  'switch': 338,
#  'no': 244,
#  'further': 166,
#  'are': 57,
#  '28': 28,
#  '2019': 19,
#  'march': 228,
#  '2023': 20,
#  '29': 29,
#  'overview': 270,
#  'allows': 46,
#  'creation': 112,
#  'servers': 316,
#  'networking': 242,
#  'collection': 91,
#  'modules': 234,
#  'various': 377,
#  'core': 108,
#  'functionalities': 164,
#  '30': 30,
#  '31': 31,
#  '32': 32,
#  'provided': 294,
#  'file': 155,
#  'system': 339,
#  'dns': 131,
#  'tcp': 341,
#  'tls': 355,
#  'ssl': 328,
#  'udp': 360,
#  'binary': 69,
#  'data': 120,
#  'buffers': 75,
#  'cryptography': 116,
#  'functions': 165,
#  'streams': 332,
#  'other': 265,
#  '33': 33,
#  'reduce': 298,
#  'complexity': 101,
#  'writing': 396,
#  'supports': 337,
#  'natively': 239,
#  'but': 78,
#  'compile': 99,
#  'available': 64,
#  '34': 34,
#  'result': 303,
#  'be': 66,
#  'coffeescript': 89,
#  '35': 35,
#  'dart': 119,
#  'typescript': 359,
#  'clojurescript': 87,
#  'others': 266,
#  'primarily': 284,
#  'network': 241,
#  'such': 333,
#  'significant': 320,
#  'difference': 128,
#  'between': 68,
#  'php': 277,
#  'block': 70,
#  'until': 366,
#  'completion': 100,
#  'commands': 94,
#  'execute': 146,
#  'previous': 282,
#  'finish': 156,
#  'while': 389,
#  'non': 246,
#  'blocking': 72,
#  'concurrently': 103,
#  'even': 143,
#  'parallel': 275,
#  '36': 36,
#  '37': 37,
#  'callbacks': 80,
#  'signal': 319,
#  'failure': 151,
#  'officially': 252,
#  'tier': 352,
#  'smartos': 325,
#  'ibm': 176,
#  'aix': 45,
#  'experimental': 149,
#  'freebsd': 163,
#  'openbsd': 257,
#  'also': 47,
#  'works': 393,
#  'lts': 220,
#  'versions': 379,
#  '400': 40,
#  '38': 38,
#  'may': 229,
#  'built': 77,
#  'similar': 321,
#  'operating': 259,
#  'systems': 340,
#  'those': 350,
#  'modified': 233,
#  'third': 347,
#  'parties': 276,
#  'nonstop': 247,
#  '39': 39}

# %%
# word_freq = {}

# for word in doc:
#     if word.text.lower() not in stop_words and word.text.lower() not in punctuation:
#         if word.text not in word_freq.keys():
#             word_freq[word.text]=1
#         else:
#             word_freq[word.text]+=1

# %%
# max_freq = max(word_freq.values())
# max_freq

# %%
# Normalization the value of the given text frequencies

# %%
# for word in word_freq.keys():
#     word_freq[word] = word_freq[word]/max_freq

# %%
# word_freq
# #normalize the value `1

# %%
sent_token = [sent for sent in doc.sents]

# %%
sent_scores = {}

for i, sent in enumerate(sent_token):
    score = 0
    vocab = vectorizer.vocabulary_
    print(f"Sentence {i}: {sent}")  # Print the sentence for debugging
    for word in sent:
        if word.text in vocab:
            word_index = vocab[word.text]
            print(f"Word: {word.text}, Word Index: {word_index}, TF-IDF Value: {tfidf_vectors[i, word_index]}")
            score += tfidf_vectors[i, word_index]
    sent_scores[sent] = score

# Now, sent_scores will contain scores for each sentence
# Out:
# Sentence 0: node.js is a cross-platform, open-source server environment that can run on windows, linux, unix, macos, and more.
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: cross, Word Index: 115, TF-IDF Value: 0.0
# Word: platform, Word Index: 279, TF-IDF Value: 0.0
# Word: open, Word Index: 256, TF-IDF Value: 0.0
# Word: source, Word Index: 326, TF-IDF Value: 0.0
# Word: server, Word Index: 315, TF-IDF Value: 0.0
# Word: environment, Word Index: 140, TF-IDF Value: 0.0
# Word: that, Word Index: 344, TF-IDF Value: 0.0
# Word: can, Word Index: 82, TF-IDF Value: 0.0
# Word: run, Word Index: 304, TF-IDF Value: 0.0
# Word: on, Word Index: 254, TF-IDF Value: 0.0
# Word: windows, Word Index: 390, TF-IDF Value: 0.0
# Word: linux, Word Index: 214, TF-IDF Value: 0.0
# Word: unix, Word Index: 364, TF-IDF Value: 0.0
# Word: macos, Word Index: 222, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: more, Word Index: 235, TF-IDF Value: 0.0
# Sentence 1: node.js is a back-end javascript runtime environment, runs on the v8 javascript engine, and executes javascript code outside a web browser.node.js lets developers use javascript to write command line tools and for server-side scripting.
# Word: is, Word Index: 192, TF-IDF Value: 1.0
# Word: back, Word Index: 65, TF-IDF Value: 0.0
# Word: end, Word Index: 137, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: runtime, Word Index: 306, TF-IDF Value: 0.0
# Word: environment, Word Index: 140, TF-IDF Value: 0.0
# Word: runs, Word Index: 305, TF-IDF Value: 0.0
# Word: on, Word Index: 254, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: v8, Word Index: 376, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: engine, Word Index: 138, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: executes, Word Index: 147, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: code, Word Index: 88, TF-IDF Value: 0.0
# Word: outside, Word Index: 268, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: lets, Word Index: 210, TF-IDF Value: 0.0
# Word: developers, Word Index: 126, TF-IDF Value: 0.0
# Word: use, Word Index: 369, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: write, Word Index: 395, TF-IDF Value: 0.0
# Word: command, Word Index: 93, TF-IDF Value: 0.0
# Word: line, Word Index: 213, TF-IDF Value: 0.0
# Word: tools, Word Index: 358, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: server, Word Index: 315, TF-IDF Value: 0.0
# Word: side, Word Index: 318, TF-IDF Value: 0.0
# Word: scripting, Word Index: 310, TF-IDF Value: 0.0
# Sentence 2: the ability to run javascript code on the server is often used to generate dynamic web page content before the page is sent to the user's web browser.
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: ability, Word Index: 41, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: run, Word Index: 304, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: code, Word Index: 88, TF-IDF Value: 0.0
# Word: on, Word Index: 254, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: server, Word Index: 315, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: often, Word Index: 253, TF-IDF Value: 0.0
# Word: used, Word Index: 370, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: generate, Word Index: 168, TF-IDF Value: 0.0
# Word: dynamic, Word Index: 134, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: page, Word Index: 273, TF-IDF Value: 0.0
# Word: content, Word Index: 107, TF-IDF Value: 0.0
# Word: before, Word Index: 67, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: page, Word Index: 273, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: sent, Word Index: 311, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: user, Word Index: 371, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: browser, Word Index: 74, TF-IDF Value: 0.0
# Sentence 3: consequently, node.js represents a "javascript everywhere" paradigm,[5] unifying web-application development around a single programming language, as opposed to using different languages for the server- versus client-side programming.node.js has an event-driven architecture capable of asynchronous i/o. these design choices aim to optimize throughput and scalability in web applications with many input/output operations, as well as for real-time web applications (e.g., real-time communication programs and browser games).[6]the node.js distributed development project was previously governed by the node.js foundation,[7] and has now merged with the js foundation to form the openjs foundation.
# Word: consequently, Word Index: 106, TF-IDF Value: 0.0
# Word: represents, Word Index: 302, TF-IDF Value: 0.0
# Word: javascript, Word Index: 197, TF-IDF Value: 0.0
# Word: everywhere, Word Index: 145, TF-IDF Value: 0.0
# Word: unifying, Word Index: 362, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: application, Word Index: 54, TF-IDF Value: 0.0
# Word: development, Word Index: 127, TF-IDF Value: 0.0
# Word: around, Word Index: 58, TF-IDF Value: 0.0
# Word: single, Word Index: 324, TF-IDF Value: 0.0
# Word: programming, Word Index: 289, TF-IDF Value: 0.0
# Word: language, Word Index: 204, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: opposed, Word Index: 261, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: using, Word Index: 372, TF-IDF Value: 0.0
# Word: different, Word Index: 129, TF-IDF Value: 0.0
# Word: languages, Word Index: 205, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: versus, Word Index: 380, TF-IDF Value: 0.0
# Word: client, Word Index: 86, TF-IDF Value: 0.0
# Word: side, Word Index: 318, TF-IDF Value: 0.0
# Word: has, Word Index: 173, TF-IDF Value: 0.0
# Word: an, Word Index: 49, TF-IDF Value: 0.0
# Word: event, Word Index: 144, TF-IDF Value: 0.0
# Word: driven, Word Index: 132, TF-IDF Value: 0.0
# Word: architecture, Word Index: 56, TF-IDF Value: 0.0
# Word: capable, Word Index: 83, TF-IDF Value: 0.0
# Word: of, Word Index: 251, TF-IDF Value: 0.0
# Word: asynchronous, Word Index: 61, TF-IDF Value: 0.0
# Word: these, Word Index: 346, TF-IDF Value: 0.0
# Word: design, Word Index: 124, TF-IDF Value: 0.0
# Word: choices, Word Index: 85, TF-IDF Value: 0.0
# Word: aim, Word Index: 44, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: optimize, Word Index: 262, TF-IDF Value: 0.0
# Word: throughput, Word Index: 351, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: scalability, Word Index: 308, TF-IDF Value: 0.0
# Word: in, Word Index: 179, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: applications, Word Index: 55, TF-IDF Value: 0.0
# Word: with, Word Index: 391, TF-IDF Value: 0.0
# Word: many, Word Index: 227, TF-IDF Value: 0.0
# Word: input, Word Index: 184, TF-IDF Value: 0.0
# Word: output, Word Index: 267, TF-IDF Value: 0.0
# Word: operations, Word Index: 260, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: well, Word Index: 386, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: real, Word Index: 296, TF-IDF Value: 0.0
# Word: time, Word Index: 353, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: applications, Word Index: 55, TF-IDF Value: 0.0
# Word: real, Word Index: 296, TF-IDF Value: 0.0
# Word: time, Word Index: 353, TF-IDF Value: 0.0
# Word: communication, Word Index: 97, TF-IDF Value: 0.0
# Word: programs, Word Index: 290, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: browser, Word Index: 74, TF-IDF Value: 0.0
# Word: distributed, Word Index: 130, TF-IDF Value: 0.0
# Word: development, Word Index: 127, TF-IDF Value: 0.0
# Word: project, Word Index: 291, TF-IDF Value: 0.0
# Word: was, Word Index: 382, TF-IDF Value: 0.0
# Word: previously, Word Index: 283, TF-IDF Value: 0.0
# Word: governed, Word Index: 171, TF-IDF Value: 0.0
# Word: by, Word Index: 79, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: has, Word Index: 173, TF-IDF Value: 0.0
# Word: now, Word Index: 249, TF-IDF Value: 0.0
# Word: merged, Word Index: 231, TF-IDF Value: 0.0
# Word: with, Word Index: 391, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: js, Word Index: 199, TF-IDF Value: 0.0
# Word: foundation, Word Index: 162, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: form, Word Index: 161, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: openjs, Word Index: 258, TF-IDF Value: 0.0
# Word: foundation, Word Index: 162, TF-IDF Value: 0.0
# Sentence 4: openjs foundation is facilitated by the linux foundation's collaborative projects program.[8]historyryan dahl, creator of node.js, in 2010
# node.js was written initially by ryan dahl in 2009,[9] about thirteen years after the introduction of the first server-side javascript environment, netscape's livewire pro web.[10] the initial release supported only linux and mac os x. its development and maintenance was led by dahl and later sponsored by joyent.[11]dahl criticized the limited possibilities of the most popular web server in 2009, apache http server, to handle a lot of concurrent connections (up to 10,000 and more) and the most common way of creating code (sequential programming), when code either blocked the entire process or implied multiple execution stacks in the case of simultaneous connections.[12]dahl demonstrated the project at the inaugural european jsconf on november 8, 2009.[13][14][15] node.js combined google's v8 javascript engine, an event loop, and a low-level i/o api.[16]in january 2010, a package manager was introduced for the node.js environment called npm.[17] the package manager makes it easier for programmers to publish and share source code of node.js packages and is designed to simplify installation, updating, and uninstallation of packages.[16]in june 2011, microsoft and joyent implemented a native windows version of node.js.[18] the first node.js build supporting windows was released in july 2011.in january 2012, dahl stepped aside, promoting coworker and npm creator isaac schlueter to manage the project.[19] in january 2014, schlueter announced that timothy j. fontaine would lead the project.[20]in december 2014, fedor indutny started io.js, a fork of node.js. due to the internal conflict over joyent's governance, io.js was created as an open governance alternative with a separate technical committee.[21][22] unlike node.js,[23] the authors planned to keep io.js up-to-date with the latest releases of the google v8 javascript engine.[24]in february 2015, the intent to form a neutral node.js foundation was announced.
# Word: openjs, Word Index: 258, TF-IDF Value: 0.0
# Word: foundation, Word Index: 162, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word
TF-IDF Value: 0.0
# Word: was, Word Index: 382, TF-IDF Value: 0.0
# Word: announced, Word Index: 51, TF-IDF Value: 0.0
# Sentence 5: by june 2015, the node.js and io.js communities voted to work together under the node.js foundation.[25]in september 2015, node.js v0.12 and io.js v3.3 were merged back together into node v4.0.[26] this merge brought v8 es6 features into node.js and a long-term support release cycle.[27] as of 2016, the io.js website recommends that developers switch back to node.js and that no further releases of io.js are planned due to the merge.[28]in 2019, the js foundation and node.js foundation merged to form the openjs foundation.on march 15 2023, node.js 19.8.1 was released.[29]overview
# node.js allows the creation of web servers and networking tools using javascript and a collection of "modules" that handle various core functionalities.[13][16][30][31][32] modules are provided for file system i/o, networking (dns, http, tcp, tls/ssl, or udp), binary data (buffers), cryptography functions, data streams, and other core functions.[16][31][33] node.js's modules use an api designed to reduce the complexity of writing server applications.[16][31]javascript is the only language that node.js supports natively, but many compile-to-js languages are available.[34] as a result, node.js applications can be written in coffeescript,[35] dart, typescript, clojurescript and others.node.js is primarily used to build network programs such as web servers.[30] the most significant difference between node.js and php is that most functions in php block until completion (commands execute only after previous commands finish), while node.js functions are non-blocking (commands execute concurrently or even in parallel,[36][37] and use callbacks to signal completion or failure).[30]node.js is officially supported on linux, macos and microsoft windows 8.1 and server 2012 (and later),[2] with tier 2 support for smartos and ibm aix and experimental support for freebsd.
# Word: by, Word Index: 79, TF-IDF Value: 0.0
# Word: june, Word Index: 202, TF-IDF Value: 0.0
# Word: 2015, Word Index: 17, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: communities, Word Index: 98, TF-IDF Value: 0.0
# Word: voted, Word Index: 381, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: work, Word Index: 392, TF-IDF Value: 0.0
# Word: together, Word Index: 357, TF-IDF Value: 0.0
# Word: under, Word Index: 361, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: september, Word Index: 313, TF-IDF Value: 0.0
# Word: 2015, Word Index: 17, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: were, Word Index: 387, TF-IDF Value: 0.0
# Word: merged, Word Index: 231, TF-IDF Value: 0.0
# Word: back, Word Index: 65, TF-IDF Value: 0.0
# Word: together, Word Index: 357, TF-IDF Value: 0.0
# Word: into, Word Index: 188, TF-IDF Value: 0.0
# Word: node, Word Index: 245, TF-IDF Value: 0.0
# Word: this, Word Index: 349, TF-IDF Value: 0.0
# Word: merge, Word Index: 230, TF-IDF Value: 0.0
# Word: brought, Word Index: 73, TF-IDF Value: 0.0
# Word: v8, Word Index: 376, TF-IDF Value: 0.0
# Word: es6, Word Index: 141, TF-IDF Value: 0.0
# Word: features, Word Index: 152, TF-IDF Value: 0.0
# Word: into, Word Index: 188, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: long, Word Index: 216, TF-IDF Value: 0.0
# Word: term, Word Index: 343, TF-IDF Value: 0.0
# Word: support, Word Index: 334, TF-IDF Value: 0.0
# Word: release, Word Index: 299, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: of, Word Index: 251, TF-IDF Value: 0.0
# Word: 2016, Word Index: 18, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: website, Word Index: 385, TF-IDF Value: 0.0
# Word: recommends, Word Index: 297, TF-IDF Value: 0.0
# Word: that, Word Index: 344, TF-IDF Value: 0.0
# Word: developers, Word Index: 126, TF-IDF Value: 0.0
# Word: switch, Word Index: 338, TF-IDF Value: 0.0
# Word: back, Word Index: 65, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: that, Word Index: 344, TF-IDF Value: 0.0
# Word: no, Word Index: 244, TF-IDF Value: 0.0
# Word: further, Word Index: 166, TF-IDF Value: 0.0
# Word: releases, Word Index: 301, TF-IDF Value: 0.0
# Word: of, Word Index: 251, TF-IDF Value: 0.0
# Word: are, Word Index: 57, TF-IDF Value: 0.0
# Word: planned, Word Index: 278, TF-IDF Value: 0.0
# Word: due, Word Index: 133, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: 2019, Word Index: 19, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: js, Word Index: 199, TF-IDF Value: 0.0
# Word: foundation, Word Index: 162, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: foundation, Word Index: 162, TF-IDF Value: 0.0
# Word: merged, Word Index: 231, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word
TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: result, Word Index: 303, TF-IDF Value: 0.0
# Word: applications, Word Index: 55, TF-IDF Value: 0.0
# Word: can, Word Index: 82, TF-IDF Value: 0.0
# Word: be, Word Index: 66, TF-IDF Value: 0.0
# Word: written, Word Index: 397, TF-IDF Value: 0.0
# Word: in, Word Index: 179, TF-IDF Value: 0.0
# Word: dart, Word Index: 119, TF-IDF Value: 0.0
# Word: typescript, Word Index: 359, TF-IDF Value: 0.0
# Word: clojurescript, Word Index: 87, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: primarily, Word Index: 284, TF-IDF Value: 0.0
# Word: used, Word Index: 370, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: build, Word Index: 76, TF-IDF Value: 0.0
# Word: network, Word Index: 241, TF-IDF Value: 0.0
# Word: programs, Word Index: 290, TF-IDF Value: 0.0
# Word: such, Word Index: 333, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: web, Word Index: 384, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: most, Word Index: 236, TF-IDF Value: 0.0
# Word: significant, Word Index: 320, TF-IDF Value: 0.0
# Word: difference, Word Index: 128, TF-IDF Value: 0.0
# Word: between, Word Index: 68, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: php, Word Index: 277, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: that, Word Index: 344, TF-IDF Value: 0.0
# Word: most, Word Index: 236, TF-IDF Value: 0.0
# Word: functions, Word Index: 165, TF-IDF Value: 0.0
# Word: in, Word Index: 179, TF-IDF Value: 0.0
# Word: php, Word Index: 277, TF-IDF Value: 0.0
# Word: block, Word Index: 70, TF-IDF Value: 0.0
# Word: until, Word Index: 366, TF-IDF Value: 0.0
# Word: completion, Word Index: 100, TF-IDF Value: 0.0
# Word: commands, Word Index: 94, TF-IDF Value: 0.0
# Word: execute, Word Index: 146, TF-IDF Value: 0.0
# Word: only, Word Index: 255, TF-IDF Value: 0.0
# Word: after, Word Index: 43, TF-IDF Value: 0.0
# Word: previous, Word Index: 282, TF-IDF Value: 0.0
# Word: commands, Word Index: 94, TF-IDF Value: 0.0
# Word: finish, Word Index: 156, TF-IDF Value: 0.0
# Word: while, Word Index: 389, TF-IDF Value: 0.0
# Word: functions, Word Index: 165, TF-IDF Value: 0.0
# Word: are, Word Index: 57, TF-IDF Value: 0.0
# Word: non, Word Index: 246, TF-IDF Value: 0.0
# Word: blocking, Word Index: 72, TF-IDF Value: 0.0
# Word: commands, Word Index: 94, TF-IDF Value: 0.0
# Word: execute, Word Index: 146, TF-IDF Value: 0.0
# Word: concurrently, Word Index: 103, TF-IDF Value: 0.0
# Word: or, Word Index: 263, TF-IDF Value: 0.0
# Word: even, Word Index: 143, TF-IDF Value: 0.0
# Word: in, Word Index: 179, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: use, Word Index: 369, TF-IDF Value: 0.0
# Word: callbacks, Word Index: 80, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: signal, Word Index: 319, TF-IDF Value: 0.0
# Word: completion, Word Index: 100, TF-IDF Value: 0.0
# Word: or, Word Index: 263, TF-IDF Value: 0.0
# Word: is, Word Index: 192, TF-IDF Value: 0.0
# Word: officially, Word Index: 252, TF-IDF Value: 0.0
# Word: supported, Word Index: 335, TF-IDF Value: 0.0
# Word: on, Word Index: 254, TF-IDF Value: 0.0
# Word: linux, Word Index: 214, TF-IDF Value: 0.0
# Word: macos, Word Index: 222, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: microsoft, Word Index: 232, TF-IDF Value: 0.0
# Word: windows, Word Index: 390, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: server, Word Index: 315, TF-IDF Value: 0.0
# Word: 2012, Word Index: 15, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: with, Word Index: 391, TF-IDF Value: 0.0
# Word: tier, Word Index: 352, TF-IDF Value: 0.0
# Word: support, Word Index: 334, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: smartos, Word Index: 325, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: ibm, Word Index: 176, TF-IDF Value: 0.0
# Word: aix, Word Index: 45, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: experimental, Word Index: 149, TF-IDF Value: 0.0
# Word: support, Word Index: 334, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: freebsd, Word Index: 163, TF-IDF Value: 0.0
# Sentence 6: openbsd also works, and lts versions available for ibm i (as/400).[38] the provided source code may also be built on similar operating systems to those officially supported or be modified by third parties to support others such as nonstop os[39] and unix servers.
# Word: openbsd, Word Index: 257, TF-IDF Value: 0.0
# Word: also, Word Index: 47, TF-IDF Value: 0.0
# Word: works, Word Index: 393, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: lts, Word Index: 220, TF-IDF Value: 0.0
# Word: versions, Word Index: 379, TF-IDF Value: 0.0
# Word: available, Word Index: 64, TF-IDF Value: 0.0
# Word: for, Word Index: 159, TF-IDF Value: 0.0
# Word: ibm, Word Index: 176, TF-IDF Value: 0.0
# Word: the, Word Index: 345, TF-IDF Value: 0.0
# Word: provided, Word Index: 294, TF-IDF Value: 0.0
# Word: source, Word Index: 326, TF-IDF Value: 0.0
# Word: code, Word Index: 88, TF-IDF Value: 0.0
# Word: may, Word Index: 229, TF-IDF Value: 0.0
# Word: also, Word Index: 47, TF-IDF Value: 0.0
# Word: be, Word Index: 66, TF-IDF Value: 0.0
# Word: built, Word Index: 77, TF-IDF Value: 0.0
# Word: on, Word Index: 254, TF-IDF Value: 0.0
# Word: similar, Word Index: 321, TF-IDF Value: 0.0
# Word: operating, Word Index: 259, TF-IDF Value: 0.0
# Word: systems, Word Index: 340, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: those, Word Index: 350, TF-IDF Value: 0.0
# Word: officially, Word Index: 252, TF-IDF Value: 0.0
# Word: supported, Word Index: 335, TF-IDF Value: 0.0
# Word: or, Word Index: 263, TF-IDF Value: 0.0
# Word: be, Word Index: 66, TF-IDF Value: 0.0
# Word: modified, Word Index: 233, TF-IDF Value: 0.0
# Word: by, Word Index: 79, TF-IDF Value: 0.0
# Word: third, Word Index: 347, TF-IDF Value: 0.0
# Word: parties, Word Index: 276, TF-IDF Value: 0.0
# Word: to, Word Index: 356, TF-IDF Value: 0.0
# Word: support, Word Index: 334, TF-IDF Value: 0.0
# Word: others, Word Index: 266, TF-IDF Value: 0.0
# Word: such, Word Index: 333, TF-IDF Value: 0.0
# Word: as, Word Index: 59, TF-IDF Value: 0.0
# Word: nonstop, Word Index: 247, TF-IDF Value: 0.0
# Word: and, Word Index: 50, TF-IDF Value: 0.0
# Word: unix, Word Index: 364, TF-IDF Value: 0.0
# Word: servers, Word Index: 316, TF-IDF Value: 0.0

# %%
type(sent_scores)
# Out:
# dict

# %%
select_len = int(len(sent_score)*0.11)
select_len
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 select_len = int(len(sent_score)*0.11)
#       2 select_len
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
from heapq import nlargest

# %%
summary = nlargest(select_len,sent_score,key=sent_score.get)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 summary = nlargest(select_len,sent_score,key=sent_score.get)
#
# NameError: name 'select_len' is not defined

# %%
summary_text = ''
for token in summary:
    summary_text +=(token.text)

summary_text

# %%
summary

# %%
len(doc.text)

# %%
len(summary_text)
